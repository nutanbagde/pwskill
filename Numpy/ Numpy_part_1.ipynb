# %%
import numpy as np

# %% [markdown]
# # conversion of list into array

# %%
l=[1,2,3,6,5,4,7,8,9]

# %%
np.array(l) # 1-Dimention array
# Out:
# array([1, 2, 3, 6, 5, 4, 7, 8, 9])

# %%
arr=np.array(l)

# %%
type(arr)
# Out:
# numpy.ndarray

# %% [markdown]
# # or by using below also you can create an array

# %%
np.asanyarray(l) # # 1-Dimention array
# Out:
# array([1, 2, 3, 6, 5, 4, 7, 8, 9])

# %%
np.array([[1,2,3],[2,3,4]]) # 2-Dimention array
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
arr1=np.array([[1,2,3],[2,3,4]])

# %%
arr.ndim # cheak the dimension of an array
# Out:
# 1

# %%
arr1.ndim # cheak the dimension of an array
# Out:
# 2

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %% [markdown]
# ![image.png](attachment:b34ee52b-8977-4771-accb-717ddcf5ce68.png)

# %% [markdown]
# ----
# ----

# %%
np.matrix(l) # it always return minimum at least 2-Dimension array

# IT IS SUBCLASS OF AARAY / OR TYPE OF ARRYA
# Out:
# matrix([[1, 2, 3, 6, 5, 4, 7, 8, 9]])

# %%
mat=np.matrix(l)

# %%
np.asanyarray(l)  # 1-D  asanyarray== it convert non-array into array(here list is converted into array)
# Out:
# array([1, 2, 3, 6, 5, 4, 7, 8, 9])

# %%
np.asanyarray(mat)  # 2-d, MATRIX IS TYPE OR SUBCLASS OF ARRAY
# Out:
# matrix([[1, 2, 3, 6, 5, 4, 7, 8, 9]])

# %% [markdown]
# ----
# ----

# %% [markdown]
# # solo copy operation

# %%
a=arr

# %%
a
# Out:
# array([1, 2, 3, 6, 5, 4, 7, 8, 9])

# %%
arr
# Out:
# array([1, 2, 3, 6, 5, 4, 7, 8, 9])

# %%
arr[0]=152

# %%
a
# Out:
# array([152,   2,   3,   6,   5,   4,   7,   8,   9])

# %%
arr
# Out:
# array([152,   2,   3,   6,   5,   4,   7,   8,   9])

# %% [markdown]
# ![image.png](attachment:79c294cd-153a-4160-b620-960f36f03a56.png)

# %% [markdown]
# abouwe
# * Here we change only in arr but automatically change in a also.
# * here we just giving a reference, here we are not creating a new memory.
# * It created the references for me
# * if you are doing any changase in arr , same changes occure in b and wise versa

# %% [markdown]
# ------
# -----

# %%
## Deep copy

# %%
b=np.copy(arr)

# %%
b
# Out:
# array([152,   2,   3,   6,   5,   4,   7,   8,   9])

# %%
arr
# Out:
# array([152,   2,   3,   6,   5,   4,   7,   8,   9])

# %%
arr[0]=500

# %%
b
# Out:
# array([152,   2,   3,   6,   5,   4,   7,   8,   9])

# %%
arr
# Out:
# array([500,   2,   3,   6,   5,   4,   7,   8,   9])

# %% [markdown]
# ![image.png](attachment:73c05581-9866-4c08-b870-7cf6e9683a78.png)

# %% [markdown]
# * Here we change only in arr but now no change in b.
# *  here we ar  creating a newsepreate  memory(2 diffrent memory location , 1 for arr and 2 for b).*
# It created thdiffrent data set pointes for .
# * if you are doing any cangase in arr , not affect in b and wise versa me

# %% [markdown]
# ----
# ----

# %% [markdown]
# # np.fromfunction(function,shape,*, dtype=<class 'float'>,like=None , kwargs,):
#
# * from this fun you can generate a data set. using function inside
# * Construct an array by executing a function over each coordinate.

# %%
np.fromfunction(lambda i,j: i==j,(3,3))
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %% [markdown]
# ![image.png](attachment:8584abfe-8e3a-4444-a8c6-d84a6c057893.png)

# %%
np.fromfunction(lambda i,j: i==j,(2,5))
# Out:
# array([[ True, False, False, False, False],
#        [False,  True, False, False, False]])

# %%
np.fromfunction(lambda i,j: i*j,(3,3))
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.]])

# %% [markdown]
# *

# %% [markdown]
# ![image.png](attachment:3fdc73bf-cd09-4f56-b308-862a1c48f2de.png)

# %% [markdown]
# ---
# ----

# %% [markdown]
# # Create a new 1-dimensional array from an iterable object.

# %%
list(i**i for i in range(5))
# Out:
# [1, 1, 4, 27, 256]

# %%
iterable=(i**i for i in range (5))

# %%
np.fromiter(iterable, float)
# Out:
# array([  1.,   1.,   4.,  27., 256.])

# %% [markdown]
# # A new 1-D array initialized from text data in a string.

# %%
np.fromstring('23 58 68 78', sep=' ')
# Out:
# array([23., 58., 68., 78.])

# %%
np.fromstring('23, 58, 68, 78', sep=', ')
# Out:
# array([23., 58., 68., 78.])

# %% [markdown]
# ---
# ---

# %% [markdown]
# # check the size of array

# %%
arr
# Out:
# array([500,   2,   3,   6,   5,   4,   7,   8,   9])

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
arr.ndim
# Out:
# 1

# %%
arr1.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 9

# %%
arr1.size
# Out:
# 6

# %%
arr.shape
# Out:
# (9,)

# %%
arr1.shape
# Out:
# (2, 3)

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
arr1.dtype
# Out:
# dtype('int32')
